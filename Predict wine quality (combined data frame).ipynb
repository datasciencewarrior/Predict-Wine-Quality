# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3 as sql
# %matplotlib inline

# %%
filename='../data/winequality-red.csv'
colnames = ['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol','quality']
df1 = pd.read_csv(filename,delimiter=';',names=colnames, header=None)
# I created a colnames as the header is messy with a bunch of words with ; in between.
df1 = df1.drop([0])

# %%
filename2='../data/winequality-white (1).csv'
colnames = ['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol','quality']
df2 = pd.read_csv(filename2,delimiter=';',names=colnames, header=None)
df2 = df2.drop([0])

# %%
df1['type'] = 'red'

# %%
df1.head()
# Out:
#   fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1           7.4              0.70         0.00             1.9      0.076
# 2           7.8              0.88         0.00             2.6      0.098
# 3           7.8              0.76         0.04             2.3      0.092
# 4          11.2              0.28         0.56             1.9      0.075
# 5           7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1                 11.0                  34.0   0.9978  3.51       0.56
# 2                 25.0                  67.0   0.9968  3.20       0.68
# 3                 15.0                  54.0   0.9970  3.26       0.65
# 4                 17.0                  60.0   0.9980  3.16       0.58
# 5                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality type
# 1      9.4      5.0  red
# 2      9.8      5.0  red
# ...

# %%
df2['type']= 'white'
df2.head()
# Out:
#   fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1             7              0.27         0.36            20.7      0.045
# 2           6.3              0.30         0.34             1.6      0.049
# 3           8.1              0.28         0.40             6.9      0.050
# 4           7.2              0.23         0.32             8.5      0.058
# 5           7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1                 45.0                 170.0   1.0010  3.00       0.45
# 2                 14.0                 132.0   0.9940  3.30       0.49
# 3                 30.0                  97.0   0.9951  3.26       0.44
# 4                 47.0                 186.0   0.9956  3.19       0.40
# 5                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality   type
# 1      8.8      6.0  white
# 2      9.5      6.0  white
# ...

# %%
frames= [df1,df2]
combine = pd.concat(frames,ignore_index=True)

# %%
combine.shape
# Out:
# (6497, 13)

# %%
combine
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              7.4              0.70         0.00             1.9      0.076
# 1              7.8              0.88         0.00             2.6      0.098
# 2              7.8              0.76         0.04             2.3      0.092
# 3             11.2              0.28         0.56             1.9      0.075
# 4              7.4              0.70         0.00             1.9      0.076
# ...            ...               ...          ...             ...        ...
# 6492           6.2              0.21         0.29             1.6      0.039
# 6493           6.6              0.32         0.36             8.0      0.047
# 6494           6.5              0.24         0.19             1.2      0.041
# 6495           5.5              0.29         0.30             1.1      0.022
# 6496             6              0.21         0.38             0.8      0.020
#
# ...

# %%
combine.corr()
# Out:
#                       volatile acidity  citric acid  residual sugar  \
# volatile acidity              1.000000    -0.377981       -0.196011
# citric acid                  -0.377981     1.000000        0.142451
# residual sugar               -0.196011     0.142451        1.000000
# chlorides                     0.377124     0.038998       -0.128940
# free sulfur dioxide          -0.352557     0.133126        0.402871
# total sulfur dioxide         -0.414476     0.195242        0.495482
# density                       0.271296     0.096154        0.552517
# pH                            0.261454    -0.329808       -0.267320
# sulphates                     0.225984     0.056197       -0.185927
# alcohol                      -0.037640    -0.010493       -0.359415
# quality                      -0.265699     0.085532       -0.036980
#
#                       chlorides  free sulfur dioxide  total sulfur dioxide  \
# ...

# %%
combine.hist(column='quality',by='type',bins=10)
plt.xticks(range(10))
plt.show()

# %%
sns.lmplot(x="quality",
y="alcohol",
data=combine,
hue="type")
#Finding one: Both red and white have higher frequency in quality 5 and 6.

# %%
sns.lmplot(x="quality",
y="density",
data=combine,
col="type")

# %%
sns.lmplot(x="quality",
y="volatile acidity",
data=combine,
col="type")
